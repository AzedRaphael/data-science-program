# %%
# Pandas visualizations are built into pandas but allow to call data visualization off a data frame
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

df = pd.read_csv('C:/Users/pc/Documents/Workspace/onecampusenv/df1.csv', index_col = 0)
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
# Create a visualized data comparison or operation on the dataframes
df['A'].hist()
# Out:
# <Axes: >

# %%
# Pandas plot types
df['B'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.head().plot(kind='bar', x='A', y='B')
# Out:
# <Axes: xlabel='A'>

# %%
df2 = pd.read_csv('C:/Users/pc/Documents/Workspace/onecampusenv/df2.csv', index_col = 0)
df2.plot.area(alpha = 0.4)
# Out:
# <Axes: xlabel='a'>

# %%
df.plot(kind='scatter', x='A', y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %%
df.plot(kind='box', y='B')
# Out:
# <Axes: >

# %%
df.plot.bar()
# Out:
# <Axes: >

# %%
df.head(20).plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar()
# Out:
# <Axes: xlabel='a'>

# %%
df2.plot.bar(stacked = True)
# Out:
# <Axes: xlabel='a'>

# %%
df['A'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
# df = df.reset_index()
df.plot.line(x = df.index, y = 'B')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 2
#       1 # df = df.reset_index()
# ----> 2 df.plot.line(x = df.index.unique, y = 'B')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:1069, in PlotAccessor.line(self, x, y, **kwargs)
#    1004 @Appender(
#    1005     """
#    1006     See Also
#    (...)
#    1061 @Appender(_bar_or_line_doc)
#    1062 def line(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1063     """
#    1064     Plot Series or DataFrame as lines.
#    1065
#    1066     This function is useful to plot lines using DataFrame's values
#    1067     as coordinates.
#    1068     """
# -> 1069     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_core.py:965, in PlotAccessor.__call__(self, *args, **kwargs)
# ...

# %%
# df.plot.scatter(x='A', y='B', c='C')
df.plot.scatter(x='A', y='B', s=df['C'] * 100)
# Out:
# C:\Users\pc\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1259: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='A', ylabel='B'>

# %%
# hex bin
df_hex = pd.DataFrame(np)
